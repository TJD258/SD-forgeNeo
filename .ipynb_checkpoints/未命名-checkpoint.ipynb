# %%
grep -n "control_type" /mnt/workspace/sd-webui-forge-neo-aki-v1/backend/nn/cnets/cldm.py | head -20
# Out:
#   Cell In[1], line 1
#     grep -n "control_type" /mnt/workspace/sd-webui-forge-neo-aki-v1/backend/nn/cnets/cldm.py | head -20
#             ^
# SyntaxError: invalid syntax

# %%
from modelscope import snapshot_download

# 1. 确保目标文件夹存在（养成好习惯）
import os
target_folder = '/mnt/workspace/sd-webui-forge-neo-aki-v1/models'
os.makedirs(target_folder, exist_ok=True)

# 2. 使用 local_dir 直接下载到目标文件夹
model_dir = snapshot_download(
    'Qwen/Qwen-Image-2512/vae/diffusion_pytorch_model.safetensors'
    local_dir=target_folder  # 关键参数：直接指定本地绝对路径
)

print(f"✅ 模型已成功下载到: {model_dir}")
# Out:
#   Cell In[3], line 10
#     'Qwen/Qwen-Image-2512/vae/diffusion_pytorch_model.safetensors'
#     ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
from modelscope import snapshot_download
import os

# 1. 确保目标文件夹存在（养成好习惯）
target_folder = '/mnt/workspace/sd-webui-forge-neo-aki-v1/models'
os.makedirs(target_folder, exist_ok=True)

# 2. 使用 local_dir 直接下载到目标文件夹
model_dir = snapshot_download(
    'Qwen/Qwen-Image-2512',  # 👈 注意：这里补上了逗号！并且建议使用模型仓库ID
    local_dir=target_folder, # 关键参数：直接指定本地绝对路径
    allow_patterns=["vae/diffusion_pytorch_model.safetensors"] # 👈 可选：如果你只想下载这一个特定文件
)

print(f"✅ 模型已成功下载到: {model_dir}")
# Out:
# 2026-08-04 13:02:00,539 | INFO    | modelscope_hub.download | Downloading 1 files from Qwen/Qwen-Image-2512@master
# Downloading:   0%|          | 0/1 [00:00<?, ?file/s]
# /usr/local/lib/python3.11/site-packages/modelscope_hub/_download.py:588: FutureWarning: Environment variable 'INTRA_CLOUD_ACCELERATION_REGION' is deprecated, use 'MODELSCOPE_DOWNLOAD_INTRA_CLOUD_REGION' instead.
#   self._download_with_resume(
# diffusion_pytorch_model.safetensors:   0%|          | 0.00/254M [00:00<?, ?B/s]
# ✅ 模型已成功下载到: /mnt/workspace/sd-webui-forge-neo-aki-v1/models

# %%
from modelscope import snapshot_download
import os

# 1. 确保目标文件夹存在
target_folder = '/mnt/workspace/sd-webui-forge-neo-aki-v1/models'
os.makedirs(target_folder, exist_ok=True)

# 2. 使用 local_dir 直接下载到目标文件夹
model_dir = snapshot_download(
    'Qwen/Qwen-Image-2512/text_encoder', 
    local_dir=target_folder, 
    allow_patterns=["model-00003-of-00004.safetensors"] # 👈 可选：如果你只想下载这一个特定文件
)

print(f"✅ 模型已成功下载到: {model_dir}")
# Out:
# ---------------------------------------------------------------------------
# NotExistError                             Traceback (most recent call last)
# File /usr/local/lib/python3.11/site-packages/modelscope_hub/compat/snapshot_download.py:84, in snapshot_download(model_id, revision, cache_dir, local_dir, allow_file_pattern, ignore_file_pattern, allow_patterns, ignore_patterns, max_workers, cookies, repo_id, repo_type, token, endpoint, local_files_only, user_agent, progress_callbacks)
#      83 try:
# ---> 84     result = api.download_repo(
#      85         effective_id,
#      86         repo_type=effective_type,
#      87         revision=revision,
#      88         cache_dir=effective_cache,
#      89         local_dir=effective_local,
#      90         allow_patterns=include,
#      91         ignore_patterns=exclude,
#      92         max_workers=max_workers,
#      93         local_files_only=local_files_only,
#      94         user_agent=user_agent,
# ...

# %%
from modelscope import snapshot_download
import os

# 1. 确保目标文件夹存在
target_folder = '/mnt/workspace/sd-webui-forge-neo-aki-v1/models'
os.makedirs(target_folder, exist_ok=True)

# 2. 使用 local_dir 直接下载到目标文件夹
model_dir = snapshot_download(
    'Qwen/Qwen-Image-2512', 
    local_dir=target_folder, 
    allow_patterns=["text_encoder/model-00003-of-00004.safetensors"] # 👈 可选：如果你只想下载这一个特定文件
)

print(f"✅ 模型已成功下载到: {model_dir}")
# Out:
# 2026-08-04 13:05:42,274 | INFO    | modelscope_hub.download | Downloading 1 files from Qwen/Qwen-Image-2512@master
# Downloading:   0%|          | 0/1 [00:00<?, ?file/s]
# model-00003-of-00004.safetensors:   0%|          | 0.00/4.93G [00:00<?, ?B/s]
# ✅ 模型已成功下载到: /mnt/workspace/sd-webui-forge-neo-aki-v1/models

# %%
from modelscope import snapshot_download
import os

# 1. 确保目标文件夹存在
target_folder = '/mnt/workspace/sd-webui-forge-neo-aki-v1/models'
os.makedirs(target_folder, exist_ok=True)

# 2. 使用 local_dir 直接下载到目标文件夹
model_dir = snapshot_download(
    'Qwen/Qwen-Image-2512', 
    local_dir=target_folder, 
    allow_patterns=["transformer/diffusion_pytorch_model-00007-of-00009.safetensors"] # 👈 可选：如果你只想下载这一个特定文件
)

print(f"✅ 模型已成功下载到: {model_dir}")
# Out:
# 2026-08-04 13:30:37,045 | INFO    | modelscope_hub.download | Downloading 1 files from Qwen/Qwen-Image-2512@master
# Downloading:   0%|          | 0/1 [00:00<?, ?file/s]
# diffusion_pytorch_model-00007-of-00009.safetensors:   0%|          | 0.00/4.91G [00:00<?, ?B/s]
# ✅ 模型已成功下载到: /mnt/workspace/sd-webui-forge-neo-aki-v1/models

# %%
from modelscope import snapshot_download
import os

# 1. 确保目标文件夹存在
target_folder = '/mnt/workspace/sd-webui-forge-neo-aki-v1/models'
os.makedirs(target_folder, exist_ok=True)

# 2. 使用 local_dir 直接下载到目标文件夹
model_dir = snapshot_download(
    'Qwen/Qwen-Image-Edit-2511', 
    local_dir=target_folder, 
    allow_patterns=["transformer/diffusion_pytorch_model-00004-of-00005.safetensors"] # 👈 可选：如果你只想下载这一个特定文件
)

print(f"✅ 模型已成功下载到: {model_dir}")
# Out:
# 2026-08-04 13:35:18,320 | INFO    | modelscope_hub.download | Downloading 1 files from Qwen/Qwen-Image-Edit-2511@master
# Downloading:   0%|          | 0/1 [00:00<?, ?file/s]
# diffusion_pytorch_model-00004-of-00005.safetensors:   0%|          | 0.00/9.93G [00:00<?, ?B/s]
# ✅ 模型已成功下载到: /mnt/workspace/sd-webui-forge-neo-aki-v1/models

# %%
from modelscope import snapshot_download
import os

# 1. 确保目标文件夹存在
target_folder = '/mnt/workspace/sd-webui-forge-neo-aki-v1/models'
os.makedirs(target_folder, exist_ok=True)

# 2. 使用 local_dir 直接下载到目标文件夹
model_dir = snapshot_download(
    'Qwen/Qwen-Image-2512', 
    local_dir=target_folder, 
    allow_patterns=["vae/diffusion_pytorch_model.safetensors"] # 👈 可选：如果你只想下载这一个特定文件
)

print(f"✅ 模型已成功下载到: {model_dir}")
# Out:
# 2026-08-04 13:38:16,677 | INFO    | modelscope_hub.download | Downloading 1 files from Qwen/Qwen-Image-2512@master
# Downloading:   0%|          | 0/1 [00:00<?, ?file/s]
# diffusion_pytorch_model.safetensors:   0%|          | 0.00/254M [00:00<?, ?B/s]
# ✅ 模型已成功下载到: /mnt/workspace/sd-webui-forge-neo-aki-v1/models

# %%
from modelscope import snapshot_download
import os

# 1. 确保目标文件夹存在
target_folder = '/mnt/workspace/sd-webui-forge-neo-aki-v1/models'
os.makedirs(target_folder, exist_ok=True)

# 2. 使用 local_dir 直接下载到目标文件夹
model_dir = snapshot_download(
    'Qwen/Qwen-Image-2512', 
    local_dir=target_folder, 
    allow_patterns=["text_encoder/model-00003-of-00004.safetensors"] # 👈 可选：如果你只想下载这一个特定文件
)

print(f"✅ 模型已成功下载到: {model_dir}")
# Out:
# 2026-08-04 13:39:18,904 | INFO    | modelscope_hub.download | Downloading 1 files from Qwen/Qwen-Image-2512@master
# Downloading:   0%|          | 0/1 [00:00<?, ?file/s]
# model-00003-of-00004.safetensors:   0%|          | 0.00/4.93G [00:00<?, ?B/s]
# ✅ 模型已成功下载到: /mnt/workspace/sd-webui-forge-neo-aki-v1/models
