# %%
# !./start_forge.sh
# Out:
# ...
#   SD Forge ModelScope 启动
# ...
#
# Python: Python 3.12.13
# 工作目录: /mnt/workspace/sd-webui-forge-neo-aki-v1
#
# 安装 cloudflared...
# 从项目目录复制 cloudflared...
# ✓ cloudflared 安装完成 (从项目目录复制)
#
# 检查依赖...
# ✓ gradio: 4.40.0
# ✓ torch: 2.11.0+gitd0c8b1f
#
# 启动 SD Forge (高性能模式)...
#
# 等待 SD Forge 启动 (30秒)...
# Python 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# Version: neo
# Installing requirements
# Installing requirements
# Launching Web UI with arguments: --listen --port 7860 --skip-python-version-check --disable-xformers --highvram --theme dark
# Total VRAM 196288 MB, total RAM 204800 MB       memory_management.py :: INFO
# PyTorch Version: 2.11.0+gitd0c8b1f              memory_management.py :: INFO
# AMD Arch: gfx942:sramecc+:xnack-                memory_management.py :: INFO
# ROCm Version: (7, 2)                            memory_management.py :: INFO
# VRAM State: HIGH_VRAM                           memory_management.py :: INFO
# ...
